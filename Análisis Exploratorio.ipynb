# %% [markdown]
# # 1. Importar librerías

# %%
import pandas as pd
import numpy as np
import plotly.express as px
df = pd.read_csv('Datasets/datos_limpios.csv')

# %% [markdown]
# # 2. Importar datos

# %%
df = pd.read_csv('Datasets/datos_limpios.csv')

# %%
df.head()
# Out:
#    employee_id  age attrition    business_travel              department  \
# 0            1   51        No      Travel_Rarely                   Sales
# 1            2   31       Yes  Travel_Frequently  Research & Development
# 2            3   32        No  Travel_Frequently  Research & Development
# 3            4   38        No         Non_Travel  Research & Development
# 4            5   32        No      Travel_Rarely  Research & Development
#
#    distance_from_home                     education education_field  gender  \
# 0                   6                 Universitario   Life Sciences  Female
# 1                  10  Por debajo de la universidad   Life Sciences  Female
# 2                  17                        Máster           Other    Male
# 3                   2                        Doctor   Life Sciences    Male
# 4                  10  Por debajo de la universidad         Medical    Male
#
# ...

# %% [markdown]
# # 3. Análisis univariado

# %% [markdown]
# ## 3.1. Análisis de variables categóricas

# %% [markdown]
# ## 3.2. Análisis de variables numéricas

# %% [markdown]
# # 4. Análisis multivariado

# %% [markdown]
# ## 4.1. Categóricas - Variable objetivo

# %% [markdown]
# ## 4.2. Numéricas - Variable objetivo

# %% [markdown]
# # 5. Análisis de correlación
